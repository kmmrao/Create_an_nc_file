# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects
import sys as s
import os 
import pandas as pd
from cartopy import config
import cartopy.crs as ccrs
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

path = r'D:\Aerosol Mixing Ratio'
file_28 = '\MERRA2_400.inst3_3d_aer_Nv.20180828.hdf'
hf_28 = h5py.File(path+file_28, 'r')

latu = np.array(hf_28['lat'])
lev = np.array(hf_28['lev'])
lon = np.array(hf_28['lon'])
time = np.array(hf_28['time'])
DU001_28 = np.array(hf_28['DU001'])
DU002_28 = np.array(hf_28['DU002'])
DU003_28 = np.array(hf_28['DU003'])
DU004_28 = np.array(hf_28['DU004'])
DU005_28 = np.array(hf_28['DU005'])
DU001_28.shape

DU1_28 = np.mean(DU001_28, axis = 0)
DU2_28 = np.mean(DU002_28, axis = 0)
DU3_28 = np.mean(DU003_28, axis = 0)
DU4_28 = np.mean(DU004_28, axis = 0)
DU5_28 = np.mean(DU005_28, axis = 0)
DU5_28.shape

d1_28 = DU1_28[:,:,384]
d2_28 = DU1_28[:,:,384]
d3_28 = DU1_28[:,:,384]
d4_28 = DU1_28[:,:,384]
d5_28 = DU1_28[:,:,384]

aug28 = d1_28+d2_28+d3_28+d4_28+d5_28
aug28_nom = aug28/10e-9 

aug28_nom_flp = np.flip(aug28_nom)
aug28_xls= pd.DataFrame(aug28_nom_flp)

aug28_xls.to_excel('aug28.xlsx')

plt.pcolor(latu,lev,aug28_nom_flp,vmin = 0, vmax =1 ,cmap='turbo',shading='auto')
plt.savefig('aug29.jpg',dpi=1080)

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects
import sys as s
import os 
import pandas as pd
from cartopy import config
import cartopy.crs as ccrs
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

path = r'D:\Aerosol Mixing Ratio'
file_29 = '\MERRA2_400.inst3_3d_aer_Nv.20180829.hdf'
hf_29 = h5py.File(path+file_29, 'r')

hf_29

latu = np.array(hf_29['lat'])
lev = np.array(hf_29['lev'])
lon = np.array(hf_29['lon'])
time = np.array(hf_29['time'])
DU001_29 = np.array(hf_29['DU001'])
DU002_29 = np.array(hf_29['DU002'])
DU003_29 = np.array(hf_29['DU003'])
DU004_29 = np.array(hf_29['DU004'])
DU005_29 = np.array(hf_29['DU005'])
DU001_29.shape

DU1_29 = np.mean(DU001_29, axis = 0)
DU2_29 = np.mean(DU002_29, axis = 0)
DU3_29 = np.mean(DU003_29, axis = 0)
DU4_29 = np.mean(DU004_29, axis = 0)
DU5_29 = np.mean(DU005_29, axis = 0)
DU5_29.shape

d1_29 = DU1_29[:,:,390]
d2_29 = DU1_29[:,:,390]
d3_29 = DU1_29[:,:,390]
d4_29 = DU1_29[:,:,390]
d5_29 = DU1_29[:,:,390]

aug29 = d1_29+d2_29+d3_29+d4_29+d5_29
aug29_nom = aug29/10e-9 

aug29_nom_flp = np.flip(aug29_nom)
aug29_xls= pd.DataFrame(aug29_nom_flp)

aug29_xls.to_excel('aug29.xlsx')

plt.pcolor(latu,lev,aug29_nom_flp,vmin = 0, vmax =1 ,cmap='turbo',shading='auto')
plt.savefig('aug29.jpg',dpi=1080)

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects
import sys as s
import os 
import pandas as pd
from cartopy import config
import cartopy.crs as ccrs
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

path = r'D:\Aerosol Mixing Ratio'
file_30 = '\MERRA2_400.inst3_3d_aer_Nv.20180830.hdf'
hf_30 = h5py.File(path+file_30, 'r')

hf_30

latu = np.array(hf_30['lat'])
lev = np.array(hf_30['lev'])
lon = np.array(hf_30['lon'])
time = np.array(hf_30['time'])
DU001_30 = np.array(hf_30['DU001'])
DU002_30 = np.array(hf_30['DU002'])
DU003_30 = np.array(hf_30['DU003'])
DU004_30 = np.array(hf_30['DU004'])
DU005_30 = np.array(hf_30['DU005'])
DU001_30.shape

DU1_30 = np.mean(DU001_30, axis = 0)
DU2_30 = np.mean(DU002_30, axis = 0)
DU3_30 = np.mean(DU003_30, axis = 0)
DU4_30 = np.mean(DU004_30, axis = 0)
DU5_30 = np.mean(DU005_30, axis = 0)
DU5_30.shape

d1_30 = DU1_30[:,:,404]
d2_30 = DU1_30[:,:,404]
d3_30 = DU1_30[:,:,404]
d4_30 = DU1_30[:,:,404]
d5_30 = DU1_30[:,:,404]

aug30 = d1_30+d2_30+d3_30+d4_30+d5_30
aug30_nom = aug30/10e-9 

aug30_nom_flp = np.flip(aug30_nom)
aug30_xls= pd.DataFrame(aug30_nom_flp)

aug30_xls.to_excel('aug30.xlsx')

plt.pcolor(latu,lev,aug30_nom_flp,vmin = 0, vmax =1 ,cmap='turbo',shading='auto')
plt.savefig('aug30.jpg',dpi=1080)

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects
import sys as s
import os 
import pandas as pd
from cartopy import config
import cartopy.crs as ccrs
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

path = r'D:\Aerosol Mixing Ratio'
file_31 = '\MERRA2_400.inst3_3d_aer_Nv.20180831.hdf'
hf_31 = h5py.File(path+file_31, 'r')

hf_31

latu = np.array(hf_31['lat'])
lev = np.array(hf_31['lev'])
lon = np.array(hf_31['lon'])
time = np.array(hf_31['time'])
DU001_31 = np.array(hf_31['DU001'])
DU002_31 = np.array(hf_31['DU002'])
DU003_31 = np.array(hf_31['DU003'])
DU004_31 = np.array(hf_31['DU004'])
DU005_31 = np.array(hf_31['DU005'])
DU001_31.shape

DU1_31 = np.mean(DU001_31, axis = 0)
DU2_31 = np.mean(DU002_31, axis = 0)
DU3_31 = np.mean(DU003_31, axis = 0)
DU4_31 = np.mean(DU004_31, axis = 0)
DU5_31 = np.mean(DU005_31, axis = 0)
DU5_31.shape

d1_31 = DU1_31[:,:,412]
d2_31 = DU1_31[:,:,412]
d3_31 = DU1_31[:,:,412]
d4_31 = DU1_31[:,:,412]
d5_31 = DU1_31[:,:,412]

aug31 = d1_31+d2_31+d3_31+d4_31+d5_31
aug31_nom = aug31/10e-9 

aug31_nom_flp = np.flip(aug31_nom)
aug31_xls= pd.DataFrame(aug31_nom_flp)

aug31_xls.to_excel('aug31.xlsx')

plt.pcolor(latu,lev,aug31_nom_flp,vmin = 0, vmax =1 ,cmap='turbo',shading='auto')
plt.savefig('aug31.jpg',dpi=1080)

# %%
m2levs = pd.read_excel('D:/New_Life/Notebooks/core/merra2_vertical_72_layers.xlsx',usecols = 'A:D')
bt1700 = pd.read_excel('C:/Users/kmmra/OneDrive/Desktop/Draft/plots and figures/data/Backtrajectories/Made_1700mts_1900Hrs.xlsx',
                  usecols = 'N:Q', skiprows=11)
bt2700 = pd.read_excel('C:/Users/kmmra/OneDrive/Desktop/Draft/plots and figures/data/Backtrajectories/2700mts_1900Hrs.xlsx',
                       usecols = 'N:Q', skiprows=9)

# %%
print(bt1700.columns)
bt2700.columns

# %%
lev_no = m2levs['L']
alt_km = m2levs['Altitude(km)']
p_hp = m2levs['Pressure(hpa)']
lat = np.array(hf_31['lat'])
lat2700 = np.array(bt2700['Lat2700'])
lon2700 = np.array(bt2700['Lon2700'])
alt2700 = np.array(bt2700['Altitude2700'])
hpa2700 = np.array(bt2700['hpa2700'])

lat1700 = np.array(bt1700['Lat1700'])
lon1700 = np.array(bt1700['Lon1700'])
alt1700 = np.array(bt1700['Height1700'])
hpa1700 = np.array(bt1700['Pressure1700'])
da = [28,29,30,31]
   



# m2levs.columns

# %%
import netCDF4 as nc

fn = 'C:/Users/kmmra/final_data_file.nc'
ds = nc.Dataset(fn, 'w', format='NETCDF4')


lat = ds.createDimension('lat', len(latu))
lon_28 = ds.createDimension('lon_28', 1)
lon_29 = ds.createDimension('lon_29', 1)
lon_30 = ds.createDimension('lon_30', 1)
lon_31 = ds.createDimension('lon_31', 1)
alt = ds.createDimension('alt', len(alt_km))
hpa = ds.createDimension('hpa', len(p_hp))
day = ds.createDimension('day',4)
lat270 = ds.createDimension('lat270',len(lat2700))
lon270 = ds.createDimension('lon270',len(lon2700))
alt270 = ds.createDimension('alt270',len(alt2700))
hpa270 = ds.createDimension('hpa270',len(hpa2700))
lat170 = ds.createDimension('lat170',len(lat1700))
lon170 = ds.createDimension('lon170',len(lon1700))
alt170 = ds.createDimension('alt170',len(alt1700))
hpa170 = ds.createDimension('hpa170',len(hpa1700))

# %%
lats = ds.createVariable('Latitude', 'f4', ('lat')) # f4 means float 32
alts = ds.createVariable('Altitude', 'f4', ('alt',))
p_hpa = ds.createVariable('Pressure_Levels', 'f4', ('hpa',))
lon_028 = ds.createVariable('lat_on_28','f4',('lon_28',))
# lon_029 = ds.createVariable('lat_on_29','f4',('lon_29',))
# lon_030 = ds.createVariable('lat_on_30','f4',('lon_30',))
# lon_031 = ds.createVariable('lat_on_31','f4',('lon_31',))
days = ds.createVariable('Days','f4',('day',))
lat27s = ds.createVariable('lat27','f4',('lat270',))
lon27s = ds.createVariable('lon27','f4',('lon270',))
alt27s = ds.createVariable('alt27','f4',('alt270',))
hpa27s = ds.createVariable('hpa27','f4',('hpa270',))
lat17s = ds.createVariable('lat17','f4',('lat170',))
lon17s = ds.createVariable('lon17','f4',('lon170',))
alt17s = ds.createVariable('alt17','f4',('alt170',))
hpa17s = ds.createVariable('hpa17','f4',('hpa170',))
dust_variable = ds.createVariable('Dust_data','f4',('day','hpa','lat'))



p_hpa.units = 'Hectapascal'
lats.units = 'Degrees'
alts.units = 'Kilometers'
dust_variable.units = 'Dobson Unit'

lats[:] =latu
alts[:] =alt_km
p_hpa[:]=p_hp
lon_028[:] = [60] 
# lon_029[:] = [64]
# lon_030[:] = [72.5]
# lon_031[:] = [77.5]
dust_variable[0, :, :] = aug28_nom_flp
dust_variable[1, :, :] = aug29_nom_flp
dust_variable[2, :, :] = aug30_nom_flp
dust_variable[3, :, :] = aug31_nom_flp
lat27s[:] = lat2700
lon27s[:] = lon2700
alt27s[:] = alt2700
hpa27s[:] = hpa2700
lat17s[:] = lat1700
lon17s[:] = lon1700
alt17s[:] = alt1700
hpa17s[:] = hpa1700
days[:] = da

# %%
ds.close()
